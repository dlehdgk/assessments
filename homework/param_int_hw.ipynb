# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('assessments'))))
from analyser import *

# %%
hw = Test('data/param_int.csv')
raw = hw.marks()

# %%
heatmap_data = hw.mark_table.set_index("Name")
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap of Student Scores")
plt.show()

# %%
melted = hw.marks(norm=True,to_one=False)

# %%
ax = sns.barplot(data=melted,x='Question',y='Mark',hue='Question', errorbar=None)
for container in ax.containers:
    labels = [f'{v.get_height():.3g}' for v in container]  # Round to 3 significant figures
    ax.bar_label(container, labels=labels, fontsize=10)
plt.title('Parametric Integration')
plt.savefig('figures/p4_ch6_param.png',dpi=300)

# %%
print(hw.total_marks_table[['Name','Total']])
# Out:
#         Name  Total
# 1        Lee   24.0
# 2   Seongjae   24.0
# 3      Benji   19.0
# 4     Taeeun   14.0
# 5   Yunjeong   24.0
# 6   Seoyeong   22.0
# 7     Elliot   24.0
# 8   Youngjae    0.0
# 9      Daeun    0.0
# 10       Jay    0.0

# %%
print(hw.norm_total[['Name','Total']])
# Out:
#         Name     Total
# 1        Lee  1.000000
# 2   Seongjae  1.000000
# 3      Benji  0.791667
# 4     Taeeun  0.583333
# 5   Yunjeong  1.000000
# 6   Seoyeong  0.916667
# 7     Elliot  1.000000
# 8   Youngjae  0.000000
# 9      Daeun  0.000000
# 10       Jay  0.000000

# %%
hist = sns.histplot(hw.total_marks_table, x = 'Total',kde=True)
data = f'mean: %.3f, standard deviation: %.3f'%(np.mean(hw.total_marks_table['Total']),np.std(hw.total_marks_table['Total']))
hist.set_title('Chapter 6 - Parametric Integration')
hist.annotate(data, (0,5))
plt.savefig('figures/Chapter 6 - Parametric Integration.png',dpi=300)
