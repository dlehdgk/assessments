# %%
from analyser import *

# %%
hw = Test('Homework/partial_binomial.csv')

# %%
heatmap_data = hw.mark_table.set_index("Name")
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap of Student Scores")
plt.show()

# %%
melted = hw.marks(norm=True,to_one=False)

# %%
partial = melted[melted['Part'].str.contains('p',na=False)]
binomial = melted[melted['Part'].str.contains('b',na=False)]

# %%
sns.barplot(data=partial,x='Question',y='Mark',hue='Question')
plt.title('Partial Fractions')
# Out:
# Text(0.5, 1.0, 'Partial Fractions')

# %%
sns.barplot(data=binomial,x='Question',y='Mark', hue='Question')
plt.title('Binomial Expansion')
# Out:
# Text(0.5, 1.0, 'Binomial Expansion')

# %%
raw = hw.marks()

# %%
#total for partial fractions
partial_r = raw[raw['Part'].str.contains('p')]
binomial_r = raw[raw['Part'].str.contains('b')]

# %%
sum_partial = partial_r.groupby(['Name']).Mark.sum().divide(11).reset_index()
sum_binomial = binomial_r.groupby(['Name']).Mark.sum().divide(49).reset_index()

# %%
print('Partial Fractions')
print(sum_partial)
# Out:
# Partial Fractions
#        Name      Mark
# 0     Benji  1.000000
# 1     Daeun  0.909091
# 2    Elliot  1.000000
# 3       Jay  1.000000
# 4       Lee  1.000000
# 5  Seongjae  1.000000
# 6  Seoyoung  1.000000
# 7    Taeeun  1.000000
# 8  Yunjeong  1.000000

# %%
print('Binomials')
print(sum_binomial)
# Out:
# Binomials
#        Name      Mark
# 0     Benji  0.877551
# 1     Daeun  0.816327
# 2    Elliot  0.938776
# 3       Jay  0.795918
# 4       Lee  0.816327
# 5  Seongjae  0.836735
# 6  Seoyoung  0.979592
# 7    Taeeun  0.877551
# 8  Yunjeong  1.000000

# %%
print(hw.total_marks_table[['Name','Total']])
# Out:
#        Name  Total
# 1    Taeeun     54
# 2       Lee     51
# 3  Yunjeong     60
# 4  Seoyoung     59
# 5       Jay     50
# 6  Seongjae     52
# 7     Benji     54
# 8    Elliot     57
# 9     Daeun     50
